# %%
import pandas as pd

# %%
laureate_df = pd.read_csv('archive.csv')
worldcitiespop = pd.read_csv('worldcitiespop.csv')
countries = pd.read_csv('countries of the world.csv')
# Out:
# /home/user/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
laureate_df.head()
# Out:
#    Year    Category                                           Prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           Motivation Prize Share  Laureate ID  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
#
#   Laureate Type                     Full Name  Birth Date         Birth City  \
# ...

# %%
worldcitiespop.head()
# Out:
#   Country        City  AccentCity Region  Population   Latitude  Longitude
# 0      ad       aixas       Aixàs    6.0         NaN  42.483333   1.466667
# 1      ad  aixirivali  Aixirivali    6.0         NaN  42.466667   1.500000
# 2      ad  aixirivall  Aixirivall    6.0         NaN  42.466667   1.500000
# 3      ad   aixirvall   Aixirvall    6.0         NaN  42.466667   1.500000
# 4      ad    aixovall    Aixovall    6.0         NaN  42.466667   1.483333

# %%
countries.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %% [markdown]
# ALTER TABLE "prize_category" ADD FOREIGN KEY ("category_id") REFERENCES "prizes" ("category_id");
#
# ALTER TABLE "prizes" ADD FOREIGN KEY ("prize_id") REFERENCES "laureats" ("prize_info_id");
#
# ALTER TABLE "laureate_type" ADD FOREIGN KEY ("type_id") REFERENCES "laureats" ("laureat_type");
#
# ALTER TABLE "laureats" ADD FOREIGN KEY ("organization_id") REFERENCES "organization" ("organization_id");
#
# ALTER TABLE "laureats" ADD FOREIGN KEY ("birth_id") REFERENCES "birth_info" ("birth_id");
#
# ALTER TABLE "laureats" ADD FOREIGN KEY ("death_id") REFERENCES "death_info" ("death_id");
#
# ALTER TABLE "city_country" ADD FOREIGN KEY ("city_country_id") REFERENCES "birth_info" ("city_country_id");
#
# ALTER TABLE "city_country" ADD FOREIGN KEY ("city_country_id") REFERENCES "death_info" ("city_country_id");
#
# ALTER TABLE "city_country" ADD FOREIGN KEY ("city_country_id") REFERENCES "organization" ("city_country_id");
#
# ALTER TABLE "countries" ADD FOREIGN KEY ("country_id") REFERENCES "city_country" ("country_id");
#
# ALTER TABLE "cities" ADD FOREIGN KEY ("city_id") REFERENCES "city_country" ("city_id");
#
# ALTER TABLE "phones" ADD FOREIGN KEY ("phone_id") REFERENCES "countries" ("phone_id");
